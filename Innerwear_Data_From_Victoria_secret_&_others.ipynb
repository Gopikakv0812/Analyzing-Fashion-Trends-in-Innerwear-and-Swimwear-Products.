# %% [markdown]
# # About Dataset
# For this project, Data set is taken from Kaggle . They were created by extracting data from from the popular retail sites via PromptCloud's data extraction solutions:
# Sites Covered
# - Amazon
# - Victoria's Secret
# - Btemptd
# - Calvin Klein
# - Hanky Panky
# - American Eagle
# - Macy's
# - Nordstrom
# - Topshop USA

# %% [markdown]
# # Goal

# %% [markdown]
# - How does the pricing differ depending on the brand?
# - Popular brand based on the review.
# - Most popular product of brand based on rating
# - What are the most common color used by different brands?

# %%
import pandas as pd
df=[]
amazon_data=pd.read_csv("amazon_com.csv")
df.append(amazon_data)

victoria_data = pd.read_csv("victoriassecret_com.csv")
df.append(victoria_data)

btemptd_data =pd.read_csv("btemptd_com.csv")
df.append(btemptd_data)

calvin_Klein_data=pd.read_csv("calvinklein_com.csv")
df.append(calvin_Klein_data)

Hanky_Panky_data=pd.read_csv("hankypanky_com.csv")
df.append(Hanky_Panky_data)

American_Eagle_data=pd.read_csv("ae_com.csv")
df.append(American_Eagle_data)

Macys_data=pd.read_csv("macys_com.csv")
df.append(Macys_data)

Nordstrom_data=pd.read_csv("shop_nordstrom_com.csv")
df.append(Nordstrom_data)

Topshop_USA_data=pd.read_csv("us_topshop_com.csv")
df.append(Topshop_USA_data)

# %%
# combine all the data into single dataframe
final_data = pd.concat(df, ignore_index=True)
final_data
# Out:
#                                              product_name      mrp    price  \
# 0       Calvin Klein Women's Sheer Marquisette Demi Un...  $36.00   $32.40
# 1                        Wacoal Embrace Lace Bikini Panty  $27.00   $27.00
# 2          Wacoal Women's Slimline Seamless Minimizer Bra  $65.00   $65.00
# 3          Hanky Panky Womens Signature Lace Retro V-Kini  $36.00   $36.00
# 4                 Wacoal Women's Red Carpet Strapless Bra  $65.00   $65.00
# ...                                                   ...      ...      ...
# 613138                                 Floral Print Thong   $10.00   $10.00
# 613139                  Bikini Knickers by Tommy Hilfiger   $28.00   $20.00
# 613140                          **Padded Bra by Wonderbra   $44.00   $24.00
# 613141                              Branded Mini Knickers   $10.00   $10.00
# 613142                             Lace Trim Triangle Bra   $26.00   $26.00
#
#                                                   pdp_url    brand_name  \
# 0       https://www.amazon.com/-/dp/B01NAVD98J?th=1&psc=1  Calvin-Klein
# 1       https://www.amazon.com/-/dp/B0011YQFNK?th=1&psc=1        Wacoal
# 2       https://www.amazon.com/-/dp/B000T3606Q?th=1&psc=1        Wacoal
# 3       https://www.amazon.com/-/dp/B003Y6AX0Y?th=1&psc=1   Hanky-Panky
# 4       https://www.amazon.com/-/dp/B01CEBGQA0?th=1&psc=1        Wacoal
# ...                                                   ...           ...
# 613138  http://www.topshop.com/en/tsus/product/clothin...    US TOPSHOP
# 613139  http://www.topshop.com/en/tsus/product/clothin...    US TOPSHOP
# 613140  http://www.topshop.com/en/tsus/product/clothin...    US TOPSHOP
# 613141  http://www.topshop.com/en/tsus/product/clothin...    US TOPSHOP
# 613142  http://www.topshop.com/en/tsus/product/clothin...    US TOPSHOP
#
#        product_category    retailer  \
# 0                  Bras   Amazon US
# 1               Panties   Amazon US
# 2                  Bras   Amazon US
# 3               Panties   Amazon US
# 4                  Bras   Amazon US
# ...                 ...         ...
# 613138         Lingerie  Topshop US
# 613139         Lingerie  Topshop US
# 613140         Lingerie  Topshop US
# 613141         Lingerie  Topshop US
# 613142         Lingerie  Topshop US
#
#                                               description  rating  \
# 0       An unlined demi cup bra featuring sheer, sexy ...     4.5
# 1       Embrace lace bikini offers great fit and match...     4.4
# 2       Seamless underwire minimizer bra gives great s...     4.3
# 3       All-day comfort describes this figure-flatteri...     4.4
# 4       Red Carpet full figure strapless fits great, s...     4.4
# ...                                                   ...     ...
# 613138  Blue floral print thong. 86% Polyamide, 14% El...     NaN
# 613139  Get serious about your under layer this season...     NaN
# 613140  Opt for an enhanced look in this full-support ...     NaN
# 613141  Cobalt blue jersey mini knickers with perforat...     NaN
# 613142  This black triangle bra is adorned with pretty...     NaN
#
#         review_count                                   style_attributes  \
# 0               47.0  [ 72% Nylon, 28% Elastane , Imported , hook an...
# 1               91.0  [ 100% Nylon , Imported , Hand Wash , 1.2" hig...
# 2              298.0  [ Cups: 100% Polyester; Back: 71% Nylon, 29% S...
# 3               46.0  [ Made in USA , All-day comfort describes this...
# 4              747.0  [ 91% Nylon, 9% Spandex , Imported , hook and ...
# ...              ...                                                ...
# 613138           NaN                                                NaN
# 613139           NaN                                                NaN
# 613140           NaN                                                NaN
# 613141           NaN                                                NaN
# 613142           NaN                                                NaN
#
#                                               total_sizes  \
# 0       30B , 30C , 30D , 30DD , 32A , 32B , 32C , 32D...
# 1                        Small , Medium , Large , X-Large
# 2       32DD , 32DDD , 34C , 34D , 34DD , 34DDD , 36C ...
# 3                        Small , Medium , Large , X-Large
# 4       30D , 30DD , 30DDD , 30G , 32C , 32D , 32DD , ...
# ...                                                   ...
# 613138                                      2,4,6,8,10,12
# 613139                                        XS,S,M,L,XL
# 613140                  32D,34D,36D,32DD,34DD,32E,34E,36E
# 613141                                      2,4,6,8,10,12
# 613142                                   2,4,6,8,10,12,14
#
#                                            available_size      color
# 0       30B , 30C , 30D , 30DD , 32B , 32C , 32D , 32D...       Bare
# 1                                Small , Medium , X-Large      Large
# 2       32DD , 32DDD , 34C , 34D , 34DD , 34DDD , 36C ...      Black
# 3                                Small , Medium , X-Large      Large
# 4       30D , 30DD , 30DDD , 30G , 32C , 32D , 32DD , ...      Pecan
# ...                                                   ...        ...
# 613138                                            2,4,6,8  PALE BLUE
# 613139                                          XS,S,M,XL  NAVY BLUE
# 613140                                       34D,36D,32DD      BLACK
# 613141                                      2,4,6,8,10,12     COBALT
# 613142                                      2,4,6,8,10,12      BLACK
#
# [613143 rows x 14 columns]

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 613143 entries, 0 to 613142
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   product_name      613143 non-null  object
#  1   mrp               613143 non-null  object
#  2   price             613143 non-null  object
#  3   pdp_url           613143 non-null  object
#  4   brand_name        613143 non-null  object
#  5   product_category  613143 non-null  object
#  6   retailer          613143 non-null  object
#  7   description       613143 non-null  object
#  8   rating            233556 non-null  float64
#  9   review_count      222030 non-null  float64
#  10  style_attributes  156675 non-null  object
#  11  total_sizes       613143 non-null  object
#  12  available_size    613143 non-null  object
#  13  color             612466 non-null  object
# dtypes: float64(2), object(12)
# memory usage: 65.5+ MB

# %%
final_data.columns
# Out:
# Index(['product_name', 'mrp', 'price', 'pdp_url', 'brand_name',
#        'product_category', 'retailer', 'description', 'rating', 'review_count',
#        'style_attributes', 'total_sizes', 'available_size', 'color'],
#       dtype='object')

#  '$90.00 ' '$53.00 ' '$69.00 ' '$108.00 ' '$63.00 ' '$84.00 ' '$125.00 '
#  '$110.00 ' '$31.00 ' '$85.00 ' '$86.00 ' '$135.00 ' '$120.00 ' '$96.00 '
#  '$14.00 ' '$11.50 ' '$16.00 ' '$10.00 ' '$19.50 ' '$74.00 ' '$92.00 '
#  '$104.00 ' '$57.00 ' '$88.00 ' '$82.00 ' '$102.00 ' '$52.00–$56.00'
#  '$100.00 ' '$23.00–$25.00' '$75.00 ' '$89.00 ' '$6.00 ' '\xa0$20.00'
#  '\xa0$35.00' '\xa0$10.00' '\xa0$45.00' '\xa0$30.00' '\xa0$15.00'
#  '\xa0$36.00' '\xa0$12.00' '\xa0$40.00' '\xa0$22.00' '\xa0$52.00'
#  '\xa0$8.00' '\xa0$26.00' '\xa0$38.00'
#  '\xa0$35.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$10.00'
#  '\xa0$70.00' '\xa0$28.00' '\xa0$90.00' '\xa0$60.00'
#  '\xa0$35.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$20.00'
#  '\xa0$15.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$8.00'
#  '\xa0$110.00'
#  '\xa0$38.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$20.00'
#  '\xa0$20.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$10.00'
#  '\xa0$30.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$20.00'
#  '\xa0$14.00' '\xa0$68.00'
#  '\xa0$35.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$24.00'
#  '\xa0$75.00'
#  '\xa0$38.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$24.00'
#  '\xa0$20.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$12.00'
#  '\xa0$65.00' '\xa0$48.00' '\xa0$50.00' '\xa0$58.00'
#  '\xa0$38.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$12.00'
#  '\xa0$20.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$6.00'
#  '\xa0$12.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$4.00'
#  '\xa0$10.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$4.00'
#  '\xa0$20.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$15.00'
#  '\xa0$100.00' '\xa0$44.00' '\xa0$46.00'
#  '\xa0$26.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$8.00'
#  '\xa0$45.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$12.00'
#  '\xa0$46.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$15.00'
#  '\xa0$30.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$8.00']
#
# Unique values in 'price': ['$32.40 ' '$27.00 ' '$65.00 ' ...
#  '\xa0$45.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$12.00'
#  '\xa0$46.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$15.00'
#  '\xa0$30.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$8.00']
#
# Unique values in 'pdp_url': ['https://www.amazon.com/-/dp/B01NAVD98J?th=1&psc=1'
#  'https://www.amazon.com/-/dp/B0011YQFNK?th=1&psc=1'
#  'https://www.amazon.com/-/dp/B000T3606Q?th=1&psc=1' ...
#  'http://www.topshop.com/en/tsus/product/clothing-70483/lingerie-2313852/colourblock-mini-knickers-6488276'
#  'http://www.topshop.com/en/tsus/product/clothing-70483/lingerie-2313852/burnout-mesh-knickers-by-somedays-lovin-6444580'
#  'http://www.topshop.com/en/tsus/product/clothing-70483/lingerie-2313852/embellished-underwired-bra-and-mini-knickers-set-6662884']
#
# Unique values in 'brand_name': ['Calvin-Klein' 'Wacoal' 'Hanky-Panky' 'b-temptd' 'Victorias-Secret' 's'
#  'ref=w_bl_sl_l_ap_ap_web_2586685011?ie=UTF8&node=2586685011&field-lbr_brands_browse-bin=Calvin+Klein'
#  'ref=w_bl_sl_l_b_ap_web_2586451011?ie=UTF8&node=2586451011&field-lbr_brands_browse-bin=b.tempt%27d'
#  'Fila' 'Lucky-Brand'
#  'ref=w_bl_sl_l_b_ap_web_2603426011?ie=UTF8&node=2603426011&field-lbr_brands_browse-bin=Wacoal'
#  'Creative-Motion' 'Sexy-Hair' 'Nintendo' 'Compression-Comfort'
#  "Victoria's Secret" "Victoria's Secret Pink" 'WACOAL' 'Calvin Klein'
#  'HankyPanky' 'AERIE' 'AEO' 'Hanky Panky' "b.tempt'd by Wacoal"
#  'Calvin Klein Modern Cotton' 'Vanity Fair' 'Calvin Klein Performance'
#  "b.tempt'd" 'HANKY PANKY' "B.TEMPT'D BY WACOAL" 'CALVIN KLEIN'
#  'NORDSTROM LINGERIE' 'US TOPSHOP']
#
# Unique values in 'product_category': ['Bras' 'Panties' 'Strappy Lace Thong Panty'
#  'The Player by Victoria Sport Sport Bra' 'Lace Cutout Thong Panty'
#  'Lace Back No-Show Thong' 'Demi Bra' 'Lace Shortie Panty'
#  'The Wicked Unlined Uplift Bra'
#  'Lightweight by Victoria Sport Strappy Sport Bra' 'Fishnet Lace Kimono'
#  'Push-Up Bralette' 'Push-Up Bra' 'Add-1½-Cups Push-Up Bra'
#  'Mesh Front-close Bralette' 'Cutout High-neck Bralette'
#  'Strappy Push-Up Bra' 'Knockout by Victoria Sport Front-Close Sport Bra'
#  'Front-close Bralette' 'Mini Lace Bustier' 'Seamless High-neck Sport Bra'
#  'Lace Long Line Bra' 'Strappy Bandeau Top'
#  'Incredible by Victoria Sport Bra' 'Unlined Demi Bra'
#  'Lace-trim Hipkini Panty' 'Lace-trim Hiphugger Panty' 'Lace-up Bodysuit'
#  'High Leg One-Piece' 'Pineapple Cheekini Panty'
#  'Wear Everywhere Super Push' 'Satin & Lace Mini Slip'
#  'Lace-trim High-leg Brief Panty' 'Strappy V-neck Teddy'
#  'String Bikini Panty' 'Wear Everywhere Multi-Way Push-Up Bra'
#  'Braided Plunge Bralette' 'Embroidered Lace Bustier'
#  'Lace Hiphugger Panty' 'Macramé Mini Bikini'
#  'Crochet Lace Flutter Bralette' 'Backless Bra'
#  'Crochet Lace Strapless Bralette' 'Lace-up Sport Bra'
#  'Lace & Mesh Long Line Bralette' 'Crossback Satin Slip'
#  'Bold\xa0Logo-waist Shortie Panty' 'Lace-inset Bandeau Bralette'
#  'Braided Front-close Bralette' 'Lace-waist Hiphugger Panty'
#  'Hiphugger Panty' 'Perfect Shape Bra' 'Lace & Mesh Bodysuit'
#  'Lace Trim Boyshort' 'Lace-trim Satin Slip' 'Lace Easy Push-Up Bra'
#  'High-waist Brief\xa0Panty' 'Racerback Lace Bodysuit'
#  'Super Soft Lace Trim Thong' 'Bikini Panty' 'Wear Everywhere Push-Up Bra'
#  'Ultimate Unlined Mesh High-Neck Sports Bra'
#  'Lace Off-the-Shoulder Bustier' 'Lace Cross-Front Unlined Halter'
#  'Medallion Lace Teddy' 'Cool & Comfy Wireless Lightly Lined Bra'
#  'The Flutter Bralette' '2-Pack Crew Sock' 'Ultimate Pocket Legging'
#  'Mesh Halter Wrap Triangle Top' 'Split Hem Tunic'
#  'Wildflower Lace Babydoll' 'Slouchy Full-Zip' 'Super Soft Cutout Tank'
#  'Muscle Tank' 'Cotton Lounge Strappy Bralette' 'Fresh & Clean Gym Kit'
#  'Old School Logo-waist Shortie Panty' 'Push-Up Bandeau Top'
#  'Daisy Lace Sleep Tee' 'Super Soft Cropped Tank' 'High Leg Bikini'
#  'Lightly Lined Racerback Bralette' 'Super SoftMuscle Tank'
#  'Caged Racerback Sport Bra' 'Logo Elastic Short' 'Lace-up Pleated Slip'
#  'Lace Trim No Show Cheekster' 'Super Soft Lace Trim Boyshort'
#  'High-neck Wrap' 'XO Lace Bodysuit' 'COLLECTIONS' 'BRAS AND BRALETTES'
#  'PANTIES' '3 FOR 33 PANTY ESSENTIALS' 'Socks' 'Sleepwear' 'Bralettes'
#  'Panty Sets' 'Collections' 'Thongs' 'Lingerie' 'Bras-and-tops' 'Cheekies'
#  'Boybriefs' 'Bikinis' 'HiLeg Bikinis' 'Boyshorts' 'Boybrief' 'Thong'
#  'HiRise Boybriefs' 'Everyday Loves Undies 6 for $26 USD' 'Pushup Bras'
#  'Sunnie Full Coverage' 'Strapless Bras' 'Triangle' 'Move' 'Sunnie Pushup'
#  'Classic' 'Halter' 'Sunnie Demi' 'Sports Bras' 'Katie' 'New! Day To Play'
#  'Lightly Lined Bras' 'Racerback' 'Bridget' 'Unlined Bras' 'Bandeau'
#  'Longline' 'Play' 'Hannah' 'Sunnie Undies 3 for $26 USD'
#  'Sunnie Wireless' 'Summer' 'Brooke' 'Lorna Jane' 'Padded' 'New! Bandeau'
#  'Chill' 'Tomgirl' 'Plunge' 'Bra Accessories' 'Audrey'
#  'New! Sunnie Bandeau' 'Undies' 'Everyday Loves Undies 7 for $27.50 USD'
#  'Sunnie Undies $5 USD' 'HiNeck'
#  'Women - Lingerie & Shapewear - Designer Lingerie'
#  'Women - Lingerie & Shapewear - Bras'
#  'Women - Lingerie & Shapewear - Sexy Lingerie'
#  'Women - Lingerie & Shapewear - Bridal Lingerie'
#  'Women - Lingerie & Shapewear - Panties'
#  'Women - Lingerie & Shapewear - Lingerie Sets' "Women's Panties"
#  'Skin-Tone Lingerie' 'Sexy Lingerie' 'Bridal Lingerie']
#
# Unique values in 'retailer': ['Amazon US' 'Victoriassecret US' 'Btemptd US' 'Calvin Klein US'
#  'Hankypanky US' 'Ae US' 'Macys US' 'Nordstrom US' 'Topshop US']
#
# Unique values in 'description': ['An unlined demi cup bra featuring sheer, sexy fabrication and bold, contrasting edging with repeating Calvin Klein logo.'
#  'Embrace lace bikini offers great fit and matches coordinating pieces in the collection |Embrace Lace Bikini'
#  'Seamless underwire minimizer bra gives great support and lift |This Minimizer was designed for function and comfort. Perfect for the full figure woman that wants full coverage. Details include placed nosegay embroidery in satin stitching with plush rigid straps detailed with satin picot.'
#  ...
#  'Nude and pale blue colourblock mini knickers. 85% Polyamide, 15% Elastane. Machine wash.'
A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36B,36C' 'XS,S,M,L'
#  '2,4,6,8,10' 'S/M,M/L' '34C,34D,36A,36B,36C,32DD,32A,32B,32C,32D,34A,34B'
#  '4,6,8,10,12,14,2' '4,6,8,10' '32B,32C,32D,34A,34B,34C,34D,36A,36B'
#  'XS,S,M' '32B,32C,32D,34B,34C,34D,36B,36C' 'L,M,S,XS'
#  '32A,32B,32C,32D,32DD,32E,34A,34B,34C,34D,34DD,34E,36A,36B,36C,36D,36DD,36E'
#  '32B,32C,32D,34B,34C,34D,36B,36C,36D'
#  '32A,32B,32C,32D,32DD,34A,34B,34D,34DD,36A,36B,34C,36C,36D'
#  '32B,32C,32D,34A,34B,34C,34D,36B' '34B,34C,34D,34DD,36B,36D,36C,36DD'
#  '30A,30B,30C,30D,30DD,32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,36B,36C,36D'
#  '32D,34D,36D,32DD,34DD,32E,34E,36E'
#  '30A,30B,30C,30D,30E,32A,32B,32C,32D,32E,34A,34B,34C,34D,34E,36A,36B,36C,36D,36E,38A,38B,38C,38D,38E,30DD,32DD,34DD,36DD,38DD'
#  '32A,34A,36A,32B,34B,36B,32C,34C,36C,38C,30D,32D,34D,36D' 'L,M,S'
#  'L,M,S,XL,XS' '32B,32C,32D,34B,34C,34D,36A,36B,36C,36D'
#  '32A,32B,32C,32D,34A,34B,34C,34D,36A,36B,36C,36D,32DD,34DD'
#  '32A,34A,36A,32B,34B,36B,38B,32C,34C,36C,30D,32D,34D,36D']
#
# Unique values in 'available_size': ['30B , 30C , 30D , 30DD , 32B , 32C , 32D , 32DD , 34A , 34B , 34C , 34D , 34DD , 36A , 36B , 36C , 36D , 38B , 38C'
#  'Small , Medium , X-Large'
#  '32DD , 32DDD , 34C , 34D , 34DD , 34DDD , 36C , 36D , 36DD , 36DDD , 38C , 38D , 38DD , 38DDD , 40C , 40DD , 40DDD'
#  ... '32A,32B,32C,32D,34A,34B,34C,36A,36B' '32B,32C,32D,34B,34D,36B'
#  '34D,36D,32DD']
#
# Unique values in 'color': ['Bare' 'Large' 'Black' ... 'natural' 'Pale Blue' 'TBC']

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# #### 1.Checking for Null values

# %%
final_data.isnull().any()
# Out:
# product_name        False
# mrp                 False
# price               False
# pdp_url             False
# brand_name          False
# product_category    False
# retailer            False
# description         False
# rating               True
# review_count         True
# style_attributes     True
# total_sizes         False
# available_size      False
# color                True
# dtype: bool

# %% [markdown]
# Hence there are no null values present in the Dataset

# %% [markdown]
# #### 2.Checking for duplicates

# %%
final_data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 613138     True
# 613139    False
# 613140    False
# 613141     True
# 613142     True
# Length: 613143, dtype: bool

# %%
# Rows that are duplicated
duplicated_rows = final_data[final_data.duplicated()]
print(duplicated_rows)
print(final_data.duplicated().sum())
# Out:
#                                        product_name      mrp    price  \
# 472     Wacoal Women's Body By Wacoal Underwire Bra  $70.40   $70.40
# 798     Wacoal Women's Body By Wacoal Underwire Bra  $46.00   $46.00
# 908     Wacoal Women's Body By Wacoal Underwire Bra  $46.00   $46.00
# 1033    Wacoal Women's Body By Wacoal Underwire Bra  $45.99   $45.99
# 1042    Wacoal Women's Body By Wacoal Underwire Bra  $45.99   $45.99
# ...                                             ...      ...      ...
# 613136             Front Fastening Dot Triangle Bra   $38.00   $12.00
# 613137                  Lace Mini Knickers by Bonds   $28.00   $28.00
# 613138                           Floral Print Thong   $10.00   $10.00
# 613141                        Branded Mini Knickers   $10.00   $10.00
# 613142                       Lace Trim Triangle Bra   $26.00   $26.00
#
#                                                   pdp_url  brand_name  \
# 472     https://www.amazon.com/-/dp/B01N2UNJVR?th=1&psc=1      Wacoal
# 798     https://www.amazon.com/-/dp/B0066648BO?th=1&psc=1      Wacoal
# 908     https://www.amazon.com/-/dp/B0066647II?th=1&psc=1      Wacoal
# 1033    https://www.amazon.com/-/dp/B01M1O6NJ8?th=1&psc=1      Wacoal
# 1042    https://www.amazon.com/-/dp/B01M0P1SH8?th=1&psc=1      Wacoal
# ...                                                   ...         ...
# 613136  http://www.topshop.com/en/tsus/product/clothin...  US TOPSHOP
# 613137  http://www.topshop.com/en/tsus/product/clothin...  US TOPSHOP
# 613138  http://www.topshop.com/en/tsus/product/clothin...  US TOPSHOP
# 613141  http://www.topshop.com/en/tsus/product/clothin...  US TOPSHOP
# 613142  http://www.topshop.com/en/tsus/product/clothin...  US TOPSHOP
#
#        product_category    retailer  \
# 472                Bras   Amazon US
# 798                Bras   Amazon US
# 908                Bras   Amazon US
# 1033               Bras   Amazon US
# 1042               Bras   Amazon US
# ...                 ...         ...
# 613136         Lingerie  Topshop US
# 613137         Lingerie  Topshop US
# 613138         Lingerie  Topshop US
# 613141         Lingerie  Topshop US
# 613142         Lingerie  Topshop US
#
#                                               description  rating  \
# 472     Body by wacoal seamless underwire is sleek and...     4.4
# 798     Body by wacoal seamless underwire is sleek and...     4.4
# 908     Body by wacoal seamless underwire is sleek and...     4.4
# 1033    Body by wacoal seamless underwire is sleek and...     4.4
# 1042    Body by wacoal seamless underwire is sleek and...     4.4
# ...                                                   ...     ...
# 613136  Non-padded triangle bra with non-wired cups fo...     NaN
# 613137  Fleuro pink lace bikini knickers by Bonds. 94%...     NaN
# 613138  Blue floral print thong. 86% Polyamide, 14% El...     NaN
# 613141  Cobalt blue jersey mini knickers with perforat...     NaN
# 613142  This black triangle bra is adorned with pretty...     NaN
#
#         review_count                                   style_attributes  \
# 472            291.0  [ Body: 87% Nylon, 13% Lycra Spandex , Importe...
# 798            291.0  [ Body: SUPPLEX® fabric - 87% nylon / 13% span...
# 908            291.0  [ Body: 87% Supplex Nylon, 24% Spandex , Impor...
# 1033           291.0  [ hook and eye closure , Wacoal Body by Wacoal...
# 1042           291.0  [ hook and eye closure , Wacoal Body by Wacoal...
# ...              ...                                                ...
# 613136           NaN                                                NaN
# 613137           NaN                                                NaN
# 613138           NaN                                                NaN
# 613141           NaN                                                NaN
# 613142           NaN                                                NaN
#
#                                               total_sizes  \
# 472     32C , 32D , 32DD , 34B , 34C , 34D , 34DD , 36...
# 798     32C , 32D , 32DD , 34B , 34C , 34D , 34DD , 36...
# 908     32C , 32D , 32DD , 34B , 34C , 34D , 34DD , 36...
# 1033    32C , 32D , 32DD , 34B , 34C , 34D , 34DD , 36...
# 1042    32C , 32D , 32DD , 34B , 34C , 34D , 34DD , 36...
# ...                                                   ...
# 613136                                      2,4,6,8,10,12
# 613137                                           4,6,8,10
# 613138                                      2,4,6,8,10,12
# 613141                                      2,4,6,8,10,12
# 613142                                   2,4,6,8,10,12,14
#
#                                            available_size       color
# 472     32C , 32D , 32DD , 34B , 34C , 34D , 36B , 36C...   Campanula
# 798     32C , 32DD , 34B , 34C , 34D , 34DD , 36B , 36...       Black
# 908     32C , 32D , 32DD , 34B , 34D , 34DD , 36B , 36...       Black
# 1033                                            32D , 34C  Capri Blue
# 1042                                            32D , 36B  Capri Blue
# ...                                                   ...         ...
# 613136                                           4,6,8,10   PALE PINK
# 613137                                                  4   Flur Pink
# 613138                                            2,4,6,8   PALE BLUE
# 613141                                      2,4,6,8,10,12      COBALT
# 613142                                      2,4,6,8,10,12       BLACK
#
# [312117 rows x 14 columns]
# 312117

# %% [markdown]
# #### 3.Dropping Duplicated values

# %%
# dropping the duplicated rows
final_data.drop_duplicates(inplace = True)
# checking if they are removed
final_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### 4. Cells with str NULL

# %% [markdown]
# - Here in this dataset there are no null values(empty cells) but there are cells with values as  NULL(style_attributes,review_count,rating,color )
# - Now we are going to check how many value NULL are there.

# %%
def missing_value(data):
    missing_value_stats = (data.isnull().sum() / len(data)*100)
    missing_value_count = sum(missing_value_stats > 0)
    print("Number of columns with missing values:", missing_value_count)
    if missing_value_count != 0:
        print("\nMissing percentage:")
        print(missing_value_stats)
    else:
        print("No missing data")
missing_value(final_data)
# Out:
# Number of columns with missing values: 4
#
# Missing percentage:
# product_name         0.000000
# mrp                  0.000000
# price                0.000000
# pdp_url              0.000000
# brand_name           0.000000
# product_category     0.000000
# retailer             0.000000
# description          0.000000
# rating              44.752945
# review_count        47.554364
# style_attributes    79.763210
# total_sizes          0.000000
# available_size       0.000000
# color                0.084046
# dtype: float64

# %% [markdown]
# - Here style_attributes gives high percentage of missing values (79.76%), hence we are dropping this column.
# - Rating (44.752945) and review_count (47.554364) are important for analysis hence we are imputing them.

# %%
# dropping style_attributes
final_data.drop(columns=['style_attributes'], inplace=True)
final_data
# Out:
#                                              product_name      mrp    price  \
# 0       Calvin Klein Women's Sheer Marquisette Demi Un...  $36.00   $32.40
# 1                        Wacoal Embrace Lace Bikini Panty  $27.00   $27.00
# 2          Wacoal Women's Slimline Seamless Minimizer Bra  $65.00   $65.00
# 3          Hanky Panky Womens Signature Lace Retro V-Kini  $36.00   $36.00
# 4                 Wacoal Women's Red Carpet Strapless Bra  $65.00   $65.00
# ...                                                   ...      ...      ...
# 613127                                   Bra by Bluebella   $58.00   $15.00
# 613128                          Embellished Underwire Bra   $45.00   $45.00
# 613134                               No VPL Mini Knickers   $10.00   $10.00
# 613139                  Bikini Knickers by Tommy Hilfiger   $28.00   $20.00
# 613140                          **Padded Bra by Wonderbra   $44.00   $24.00
#
#                                                   pdp_url    brand_name  \
# 0       https://www.amazon.com/-/dp/B01NAVD98J?th=1&psc=1  Calvin-Klein
# 1       https://www.amazon.com/-/dp/B0011YQFNK?th=1&psc=1        Wacoal
# 2       https://www.amazon.com/-/dp/B000T3606Q?th=1&psc=1        Wacoal
# 3       https://www.amazon.com/-/dp/B003Y6AX0Y?th=1&psc=1   Hanky-Panky
# 4       https://www.amazon.com/-/dp/B01CEBGQA0?th=1&psc=1        Wacoal
# ...                                                   ...           ...
# 613127  http://www.topshop.com/en/tsus/product/clothin...    US TOPSHOP
# 613128  http://www.topshop.com/en/tsus/product/clothin...    US TOPSHOP
# 613134  http://www.topshop.com/en/tsus/product/clothin...    US TOPSHOP
# 613139  http://www.topshop.com/en/tsus/product/clothin...    US TOPSHOP
# 613140  http://www.topshop.com/en/tsus/product/clothin...    US TOPSHOP
#
#        product_category    retailer  \
# 0                  Bras   Amazon US
# 1               Panties   Amazon US
# 2                  Bras   Amazon US
# 3               Panties   Amazon US
# 4                  Bras   Amazon US
# ...                 ...         ...
# 613127         Lingerie  Topshop US
# 613128         Lingerie  Topshop US
# 613134         Lingerie  Topshop US
# 613139         Lingerie  Topshop US
# 613140         Lingerie  Topshop US
#
#                                               description  rating  \
# 0       An unlined demi cup bra featuring sheer, sexy ...     4.5
# 1       Embrace lace bikini offers great fit and match...     4.4
# 2       Seamless underwire minimizer bra gives great s...     4.3
# 3       All-day comfort describes this figure-flatteri...     4.4
# 4       Red Carpet full figure strapless fits great, s...     4.4
# ...                                                   ...     ...
# 613127  Black bra by Bluebella. 85% Polyester, 15% Ela...     NaN
# 613128  Embellished underwired bra and mini knickers s...     NaN
# 613134  Keep your outfits seam-free with these low ris...     NaN
# 613139  Get serious about your under layer this season...     NaN
# 613140  Opt for an enhanced look in this full-support ...     NaN
#
#         review_count                                        total_sizes  \
# 0               47.0  30B , 30C , 30D , 30DD , 32A , 32B , 32C , 32D...
# 1               91.0                   Small , Medium , Large , X-Large
# 2              298.0  32DD , 32DDD , 34C , 34D , 34DD , 34DDD , 36C ...
# 3               46.0                   Small , Medium , Large , X-Large
# 4              747.0  30D , 30DD , 30DDD , 30G , 32C , 32D , 32DD , ...
# ...              ...                                                ...
# 613127           NaN                32B,32C,32D,34B,34C,34D,36B,36C,36D
# 613128           NaN  30A,30B,30C,30D,30DD,32A,32B,32C,32D,32DD,34A,...
# 613134           NaN                                      2,4,6,8,10,12
# 613139           NaN                                        XS,S,M,L,XL
# 613140           NaN                  32D,34D,36D,32DD,34DD,32E,34E,36E
#
#                                            available_size      color
# 0       30B , 30C , 30D , 30DD , 32B , 32C , 32D , 32D...       Bare
# 1                                Small , Medium , X-Large      Large
# 2       32DD , 32DDD , 34C , 34D , 34DD , 34DDD , 36C ...      Black
# 3                                Small , Medium , X-Large      Large
# 4       30D , 30DD , 30DDD , 30G , 32C , 32D , 32DD , ...      Pecan
# ...                                                   ...        ...
# 613127                            32B,32C,32D,34B,34D,36B      BLACK
# 613128  30A,30B,30C,30D,32A,32B,32C,32D,34A,34B,34C,34...        NaN
# 613134                                             2,6,12       PLUM
# 613139                                          XS,S,M,XL  NAVY BLUE
# 613140                                       34D,36D,32DD      BLACK
#
# [301026 rows x 13 columns]

# %%
print(final_data[['rating', 'review_count']].isnull().sum())
# Out:
# rating          134718
# review_count    143151
# dtype: int64

# %% [markdown]
# #### 5. Outlier Detection
# - Before imputing we are plotting boxplot for checking the  outliers .

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_palette("Set1")
plt.figure(figsize=(10, 5))

# Box Plot for 'rating'
plt.subplot(1,2,1)
sns.boxplot(x=final_data['rating'].dropna())
plt.title('Box Plot for Ratings')

# Box Plot for 'review_count'
plt.subplot(1,2,2)
sns.boxplot(x=final_data['review_count'].dropna())
plt.title('Box Plot for Review Counts')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 6.Skewness of Rating and review count

# %%
print("Skewness of Ratings:", final_data['rating'].skew())
print("Skewness of Review Counts:", final_data['review_count'].skew())
# Out:
# Skewness of Ratings: -2.2949943691898538
# Skewness of Review Counts: 17.087142336279385

# %% [markdown]
# - The skewness of the rating distribution is negative (left-skewed).
# - The skewness of the review count distribution is positive (right-skewed).
# - Outliers are present in both columns.
# - Hence we need to remove these outliers before imputing so that we can choose mean or median imputation.

# %% [markdown]
# #### 7. Outlier removal

# %%
def remove_outliers(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return data[~((data[column] < lower_bound) | (data[column] > upper_bound))]

# Removing outliers from both 'rating' and 'review_count'
filtered_data = remove_outliers(final_data, 'rating')
filtered_data = remove_outliers(filtered_data, 'review_count')
filtered_data
# Out:
#                                              product_name      mrp    price  \
# 0       Calvin Klein Women's Sheer Marquisette Demi Un...  $36.00   $32.40
# 1                        Wacoal Embrace Lace Bikini Panty  $27.00   $27.00
# 2          Wacoal Women's Slimline Seamless Minimizer Bra  $65.00   $65.00
# 3          Hanky Panky Womens Signature Lace Retro V-Kini  $36.00   $36.00
# 4                 Wacoal Women's Red Carpet Strapless Bra  $65.00   $65.00
# ...                                                   ...      ...      ...
# 613127                                   Bra by Bluebella   $58.00   $15.00
# 613128                          Embellished Underwire Bra   $45.00   $45.00
# 613134                               No VPL Mini Knickers   $10.00   $10.00
# 613139                  Bikini Knickers by Tommy Hilfiger   $28.00   $20.00
# 613140                          **Padded Bra by Wonderbra   $44.00   $24.00
#
#                                                   pdp_url    brand_name  \
# 0       https://www.amazon.com/-/dp/B01NAVD98J?th=1&psc=1  Calvin-Klein
# 1       https://www.amazon.com/-/dp/B0011YQFNK?th=1&psc=1        Wacoal
# 2       https://www.amazon.com/-/dp/B000T3606Q?th=1&psc=1        Wacoal
# 3       https://www.amazon.com/-/dp/B003Y6AX0Y?th=1&psc=1   Hanky-Panky
# 4       https://www.amazon.com/-/dp/B01CEBGQA0?th=1&psc=1        Wacoal
# ...                                                   ...           ...
# 613127  http://www.topshop.com/en/tsus/product/clothin...    US TOPSHOP
# 613128  http://www.topshop.com/en/tsus/product/clothin...    US TOPSHOP
# 613134  http://www.topshop.com/en/tsus/product/clothin...    US TOPSHOP
# 613139  http://www.topshop.com/en/tsus/product/clothin...    US TOPSHOP
# 613140  http://www.topshop.com/en/tsus/product/clothin...    US TOPSHOP
#
#        product_category    retailer  \
# 0                  Bras   Amazon US
# 1               Panties   Amazon US
# 2                  Bras   Amazon US
# 3               Panties   Amazon US
# 4                  Bras   Amazon US
# ...                 ...         ...
# 613127         Lingerie  Topshop US
# 613128         Lingerie  Topshop US
# 613134         Lingerie  Topshop US
# 613139         Lingerie  Topshop US
# 613140         Lingerie  Topshop US
#
#                                               description  rating  \
# 0       An unlined demi cup bra featuring sheer, sexy ...     4.5
# 1       Embrace lace bikini offers great fit and match...     4.4
# 2       Seamless underwire minimizer bra gives great s...     4.3
# 3       All-day comfort describes this figure-flatteri...     4.4
# 4       Red Carpet full figure strapless fits great, s...     4.4
# ...                                                   ...     ...
# 613127  Black bra by Bluebella. 85% Polyester, 15% Ela...     NaN
# 613128  Embellished underwired bra and mini knickers s...     NaN
# 613134  Keep your outfits seam-free with these low ris...     NaN
# 613139  Get serious about your under layer this season...     NaN
# 613140  Opt for an enhanced look in this full-support ...     NaN
#
#         review_count                                        total_sizes  \
# 0               47.0  30B , 30C , 30D , 30DD , 32A , 32B , 32C , 32D...
# 1               91.0                   Small , Medium , Large , X-Large
# 2              298.0  32DD , 32DDD , 34C , 34D , 34DD , 34DDD , 36C ...
# 3               46.0                   Small , Medium , Large , X-Large
# 4              747.0  30D , 30DD , 30DDD , 30G , 32C , 32D , 32DD , ...
# ...              ...                                                ...
# 613127           NaN                32B,32C,32D,34B,34C,34D,36B,36C,36D
# 613128           NaN  30A,30B,30C,30D,30DD,32A,32B,32C,32D,32DD,34A,...
# 613134           NaN                                      2,4,6,8,10,12
# 613139           NaN                                        XS,S,M,L,XL
# 613140           NaN                  32D,34D,36D,32DD,34DD,32E,34E,36E
#
#                                            available_size      color
# 0       30B , 30C , 30D , 30DD , 32B , 32C , 32D , 32D...       Bare
# 1                                Small , Medium , X-Large      Large
# 2       32DD , 32DDD , 34C , 34D , 34DD , 34DDD , 36C ...      Black
# 3                                Small , Medium , X-Large      Large
# 4       30D , 30DD , 30DDD , 30G , 32C , 32D , 32DD , ...      Pecan
# ...                                                   ...        ...
# 613127                            32B,32C,32D,34B,34D,36B      BLACK
# 613128  30A,30B,30C,30D,32A,32B,32C,32D,34A,34B,34C,34...        NaN
# 613134                                             2,6,12       PLUM
# 613139                                          XS,S,M,XL  NAVY BLUE
# 613140                                       34D,36D,32DD      BLACK
#
# [291209 rows x 13 columns]

# %%
plt.figure(figsize=(10,5))
# Box Plot for 'rating'
plt.subplot(1,2,1)
sns.boxplot(x=filtered_data['rating'])
plt.title('Box Plot for Ratings-Without Outliers')

# Box Plot for 'review_count'
plt.subplot(1, 2, 2)
sns.boxplot(x=filtered_data['review_count'])
plt.title('Box Plot for Review Counts -Without Outliers')

plt.tight_layout()
plt.show()

# %%
print("Skewness of Ratings:", filtered_data['rating'].skew())
print("Skewness of Review Counts:", filtered_data['review_count'].skew())
# Out:
# Skewness of Ratings: -0.4035181640566867
# Skewness of Review Counts: 0.702816407940703

# %% [markdown]
# - In both cases, using the median for imputation is better as it provides a more reliable central tendency measure in the presence of skewed distributions.

# %% [markdown]
# #### 8.Median Imputation

# %%
# Perform median imputation correctly
filtered_data['rating'].fillna(filtered_data['rating'].median(), inplace=True)
filtered_data['review_count'].fillna(filtered_data['review_count'].median(), inplace=True)

# %% [markdown]
# #### 9.Mode imputation for Color

# %%
filtered_data['color'].fillna(filtered_data['color'].mode()[0], inplace=True)

# %% [markdown]
# #### 10. Standardize mrp &  price values

# %%
# removing space if it exists in the data
filtered_data['mrp'] = filtered_data['mrp'].str.strip()
filtered_data['price'] = filtered_data['price'].str.strip()

# remove anything that is not a number or a decimal point
filtered_data['mrp'] = filtered_data['mrp'].replace({'[^0-9.]': ''}, regex=True)
filtered_data['price'] = filtered_data['price'].replace({'[^0-9.]': ''}, regex=True)
# using pd.to_numeric
filtered_data['mrp'] = pd.to_numeric(filtered_data['mrp'], errors='coerce')
filtered_data['price'] = pd.to_numeric(filtered_data['price'], errors='coerce')

# %% [markdown]
# #### 11. Standardize Brand name

# %%
def std_brand_names(brand_name):
    brand_name = brand_name.lower().replace("-", " ")
    if "hanky" in brand_name:
        brand_name = "Hanky Panky"
    elif "calvin" in brand_name:
        brand_name = "Calvin klein"
    elif "wacoal" in brand_name or "tempt" in brand_name:
        brand_name = "B.tempt'd"
    elif "victorias" in brand_name or "victoria's" in brand_name or "s" in brand_name:
        brand_name = "Victoria's secret"
    elif "aeo" in brand_name or "aerie" in brand_name:
        brand_name = "Aerie" 
    
    brand_name = brand_name.strip()
    
    return brand_name

filtered_data['brand_name'] = filtered_data['brand_name'].apply(std_brand_names)
print(filtered_data['brand_name'].value_counts())
# Out:
# brand_name
# Victoria's secret    234524
# B.tempt'd             19039
# Aerie                 16952
# Calvin klein          12231
# Hanky Panky            7855
# vanity fair             604
# fila                      1
# lucky brand               1
# creative motion           1
# nintendo                  1
# Name: count, dtype: int64

# %% [markdown]
# #### 12.Feature Engineering
# - Discount percentage feature would be more impactful for the analysis using 'mrp' and 'price'

# %%
print(filtered_data['mrp'].isna().sum(),'for mrp')
print(filtered_data['price'].isna().sum(),'for price')
# Out:
# 90 for mrp
# 102 for price

# %% [markdown]
# #### Even after cleaning mrp and price null values are present(90 and 102 respectively). Hence we are dropping those rows .

# %%
filtered_data = filtered_data.dropna(subset=['mrp', 'price'])
print(filtered_data['mrp'].isna().sum(),'for mrp')
print(filtered_data['price'].isna().sum(),'for price')
# Out:
# 0 for mrp
# 0 for price

# %% [markdown]
# ### Feature engineering : Discount_percentage

# %%
filtered_data['discount_percentage'] = ((filtered_data['mrp'] - filtered_data['price']) / filtered_data['mrp']) * 100
filtered_data
# Out:
# C:\Users\lapto\AppData\Local\Temp\ipykernel_26532\3682061004.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['discount_percentage'] = ((filtered_data['mrp'] - filtered_data['price']) / filtered_data['mrp']) * 100
#                                              product_name   mrp  price  \
# 0       Calvin Klein Women's Sheer Marquisette Demi Un...  36.0   32.4
# 1                        Wacoal Embrace Lace Bikini Panty  27.0   27.0
# 2          Wacoal Women's Slimline Seamless Minimizer Bra  65.0   65.0
# 3          Hanky Panky Womens Signature Lace Retro V-Kini  36.0   36.0
# 4                 Wacoal Women's Red Carpet Strapless Bra  65.0   65.0
# ...                                                   ...   ...    ...
# 613127                                   Bra by Bluebella  58.0   15.0
# 613128                          Embellished Underwire Bra  45.0   45.0
# 613134                               No VPL Mini Knickers  10.0   10.0
# 613139                  Bikini Knickers by Tommy Hilfiger  28.0   20.0
# 613140                          **Padded Bra by Wonderbra  44.0   24.0
#
#                                                   pdp_url         brand_name  \
# 0       https://www.amazon.com/-/dp/B01NAVD98J?th=1&psc=1       Calvin klein
# 1       https://www.amazon.com/-/dp/B0011YQFNK?th=1&psc=1          B.tempt'd
# 2       https://www.amazon.com/-/dp/B000T3606Q?th=1&psc=1          B.tempt'd
# 3       https://www.amazon.com/-/dp/B003Y6AX0Y?th=1&psc=1        Hanky Panky
# 4       https://www.amazon.com/-/dp/B01CEBGQA0?th=1&psc=1          B.tempt'd
# ...                                                   ...                ...
# 613127  http://www.topshop.com/en/tsus/product/clothin...  Victoria's secret
# 613128  http://www.topshop.com/en/tsus/product/clothin...  Victoria's secret
# 613134  http://www.topshop.com/en/tsus/product/clothin...  Victoria's secret
# 613139  http://www.topshop.com/en/tsus/product/clothin...  Victoria's secret
# 613140  http://www.topshop.com/en/tsus/product/clothin...  Victoria's secret
#
#        product_category    retailer  \
# 0                  Bras   Amazon US
# 1               Panties   Amazon US
# 2                  Bras   Amazon US
# 3               Panties   Amazon US
# 4                  Bras   Amazon US
# ...                 ...         ...
# 613127         Lingerie  Topshop US
# 613128         Lingerie  Topshop US
# 613134         Lingerie  Topshop US
# 613139         Lingerie  Topshop US
# 613140         Lingerie  Topshop US
#
#                                               description  rating  \
# 0       An unlined demi cup bra featuring sheer, sexy ...     4.5
# 1       Embrace lace bikini offers great fit and match...     4.4
# 2       Seamless underwire minimizer bra gives great s...     4.3
# 3       All-day comfort describes this figure-flatteri...     4.4
# 4       Red Carpet full figure strapless fits great, s...     4.4
# ...                                                   ...     ...
# 613127  Black bra by Bluebella. 85% Polyester, 15% Ela...     4.3
# 613128  Embellished underwired bra and mini knickers s...     4.3
# 613134  Keep your outfits seam-free with these low ris...     4.3
# 613139  Get serious about your under layer this season...     4.3
# 613140  Opt for an enhanced look in this full-support ...     4.3
#
#         review_count                                        total_sizes  \
# 0               47.0  30B , 30C , 30D , 30DD , 32A , 32B , 32C , 32D...
# 1               91.0                   Small , Medium , Large , X-Large
# 2              298.0  32DD , 32DDD , 34C , 34D , 34DD , 34DDD , 36C ...
# 3               46.0                   Small , Medium , Large , X-Large
# 4              747.0  30D , 30DD , 30DDD , 30G , 32C , 32D , 32DD , ...
# ...              ...                                                ...
# 613127         165.0                32B,32C,32D,34B,34C,34D,36B,36C,36D
# 613128         165.0  30A,30B,30C,30D,30DD,32A,32B,32C,32D,32DD,34A,...
# 613134         165.0                                      2,4,6,8,10,12
# 613139         165.0                                        XS,S,M,L,XL
# 613140         165.0                  32D,34D,36D,32DD,34DD,32E,34E,36E
#
#                                            available_size      color  \
# 0       30B , 30C , 30D , 30DD , 32B , 32C , 32D , 32D...       Bare
# 1                                Small , Medium , X-Large      Large
# 2       32DD , 32DDD , 34C , 34D , 34DD , 34DDD , 36C ...      Black
# 3                                Small , Medium , X-Large      Large
# 4       30D , 30DD , 30DDD , 30G , 32C , 32D , 32DD , ...      Pecan
# ...                                                   ...        ...
# 613127                            32B,32C,32D,34B,34D,36B      BLACK
# 613128  30A,30B,30C,30D,32A,32B,32C,32D,34A,34B,34C,34...      Black
# 613134                                             2,6,12       PLUM
# 613139                                          XS,S,M,XL  NAVY BLUE
# 613140                                       34D,36D,32DD      BLACK
#
#         discount_percentage
# 0                 10.000000
# 1                  0.000000
# 2                  0.000000
# 3                  0.000000
# 4                  0.000000
# ...                     ...
# 613127            74.137931
# 613128             0.000000
# 613134             0.000000
# 613139            28.571429
# 613140            45.454545
#
# [291107 rows x 14 columns]

# %% [markdown]
# #### Since we have dropped style attribute column , we will be proceeding with the following goals:
# - Price Analysis by Brand
# - Topic Modeling on Product Descriptions
# - Color Analysis by Brand
# - Ratings Analysis

# %% [markdown]
# ## Price Analysis by Brand

# %%
import seaborn as sns
price_analysis = filtered_data.groupby('brand_name')['price'].agg(['mean', 'median', 'min', 'max', 'count'])
price_analysis = price_analysis.reset_index()
print(price_analysis)
# Bar chart using Seaborn
plt.figure(figsize=(12, 6))
sns.barplot(x='brand_name', y='mean', data=price_analysis.sort_values('mean'), palette='Set3')
plt.title('Mean Price by Brand')
plt.xlabel('Brand Name')
plt.ylabel('Mean Price')
plt.xticks(rotation=45)
plt.show()
# Out:
#           brand_name       mean  median    min      max   count
# 0              Aerie  16.958580   14.97   3.99   51.090   16952
# 1          B.tempt'd  44.140702   48.00   5.00   85.000   19039
# 2       Calvin klein  27.628749   26.00   4.99  125.000   12219
# 3        Hanky Panky  43.559812   34.00  10.00  615.000    7833
# 4  Victoria's secret  34.183393   34.95   2.00  543.294  234456
# 5    creative motion  21.890000   21.89  21.89   21.890       1
# 6               fila  27.000000   27.00  27.00   27.000       1
# 7        lucky brand  15.070000   15.07  15.07   15.070       1
# 8           nintendo  30.400000   30.40  30.40   30.400       1
# 9        vanity fair  29.088543   38.00   3.99   40.000     604

# %%
#Box plot for brand_name and price
plt.figure(figsize=(12, 6))
sns.boxplot(x='brand_name', y='price', data=filtered_data)
plt.title('Price Distribution by Brand')
plt.xlabel('Brand Name')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - The bar chart for Price analysis by brand name (mean price) shows that B.tempt'd is more expensive than other brands, followed by Hanky Panky and Victoria's Secret.
# - However, the box plot results indicate that Hanky Panky and Victoria's Secret have relatively wide price ranges compared to the other brands, with B.tempt'd following closely.
# - Overall, the results indicate that B.tempt'd, Hanky Panky, and Victoria's Secret are the most expensive brands. This could be due to factors such as product variety, material quality, brand recognition, or target market.

# %% [markdown]
# ## Review Analysis by Brand

# %%
# Group the data by 'brand_name' and calculate the sum of 'review_count' for each brand
review_count_by_brand = filtered_data.groupby('brand_name')['review_count'].sum().reset_index()
print(review_count_by_brand)

plt.figure(figsize=(5,5))
plt.pie(review_count_by_brand['review_count'], labels=review_count_by_brand['brand_name'], autopct='%1.1f%%', 
        startangle=180)
plt.title('Proportion of Total Review Count by Brand')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
#           brand_name  review_count
# 0              Aerie     1945665.0
# 1          B.tempt'd     7432151.0
# 2       Calvin klein     1926044.0
# 3        Hanky Panky     1006098.0
# 4  Victoria's secret    48877974.0
# 5    creative motion         376.0
# 6               fila          94.0
# 7        lucky brand          94.0
# 8           nintendo         375.0
# 9        vanity fair       90100.0

# %% [markdown]
# - Pie chart indicates that Victoria's Secret is the most popular brand in the market in terms of the review count ( almost 80% of the total) followed by B.temp'd.

# %% [markdown]
# # Popular product of brand based on rating

# %%
avg_rating_by_category = filtered_data.groupby(['brand_name', 'product_category'])['rating'].mean().reset_index()
most_popular_categories = avg_rating_by_category.loc[avg_rating_by_category.groupby('brand_name')['rating'].idxmax()]
print(most_popular_categories)

#Visualize the results
plt.figure(figsize=(12, 6))
sns.barplot(x='rating', y='product_category', hue='brand_name', data=most_popular_categories, palette='viridis')
plt.title('Most Popular Product Category by Brand Based on Average Rating')
plt.xlabel('Average Rating')
plt.ylabel('Product Category')
plt.legend(title='Brand Name', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
#             brand_name                              product_category    rating
# 11               Aerie                                      Cheekies  4.859520
# 51           B.tempt'd                               Bridal Lingerie  4.752941
# 73        Calvin klein           Women - Lingerie & Shapewear - Bras  4.463532
# 93         Hanky Panky  Women - Lingerie & Shapewear - Sexy Lingerie  4.685000
# 301  Victoria's secret                         Lace-Trim Thong Panty  4.757692
# 555    creative motion                                          Bras  4.300000
# 556               fila                                       Panties  4.300000
# 557        lucky brand                                       Panties  4.300000
# 558           nintendo                                          Bras  4.300000
# 560        vanity fair        Women - Lingerie & Shapewear - Panties  4.690286

# %% [markdown]
# - Aerie's Cheekies is the most popular product category by brand based upon the average rating(4.8).
# - Victoria's secret's Lace-Trim Thong Panty is the second most popular followed by B.tempt'd Bridal Lingerie.
# - All of the brand have rating between 4.3 to 4.8

# %% [markdown]
# # Common color used by the Brand

# %%
color_counts = filtered_data.groupby(['brand_name', 'color']).size().reset_index(name='count')
most_common_colors = color_counts.loc[color_counts.groupby('brand_name')['count'].idxmax()]
print(most_common_colors)
# Visualize the results
plt.figure(figsize=(12, 6))
sns.barplot(x='count', y='color', hue='brand_name', data=most_common_colors, palette='viridis')
plt.title('Most Common Colors Used by Different Brands')
plt.xlabel('Count of Products')
plt.ylabel('Color')
plt.legend(title='Brand Name', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
#              brand_name          color  count
# 85                Aerie     True Black   2806
# 105           B.tempt'd          Black   3195
# 391        Calvin klein          Black   1867
# 770         Hanky Panky          Black   1067
# 1104  Victoria's secret          Black   9475
# 2526    creative motion  Dazzling Blue      1
# 2527               fila         Medium      1
# 2528        lucky brand          Large      1
# 2529           nintendo        Peacoat      1
# 2596        vanity fair     Star White     74

# %% [markdown]
# - Black is a predominant color across multiple brands like  B.tempt'd ,Calvin klein ,Hanky Panky ,Victoria's secret and aerie.
# - Some unique colors are observed in smaller quantities for certain brands, such as "Star White" for Vanity fair.

# %% [markdown]
# # Correlation Analysis

# %%
numerical_columns = ['mrp', 'price', 'rating', 'review_count', 'discount_percentage']
correlation_matrix = filtered_data[numerical_columns].corr()

# visualize
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

correlation_matrix
# Out:
#                           mrp     price    rating  review_count  \
# mrp                  1.000000  0.922423 -0.024682      0.206956
# price                0.922423  1.000000  0.000582      0.239661
# rating              -0.024682  0.000582  1.000000      0.073334
# review_count         0.206956  0.239661  0.073334      1.000000
# discount_percentage -0.040770 -0.367627 -0.071401     -0.083340
#
#                      discount_percentage
# mrp                            -0.040770
# price                          -0.367627
# rating                         -0.071401
# review_count                   -0.083340
# discount_percentage             1.000000

# %% [markdown]
# - Strong positive correlation between MRP and Price.
# - Weak correlation between rating and other variables.
# - Moderate Correlation between Discount and price.
